# %%
import numpy as np
import matplotlib.pyplot as plt
def f_1(x):
    return np.cos(1 * diap)
def f_2(x):
    return np.cos(3 * diap)
diap = np.linspace(0, 3, 100)  # 51 точка между 0 и 3
y_1 = f_1(diap)
y_2 = f_2(diap)
plt.plot(diap, y_1)
plt.plot(diap, y_2)
plt.show()
